# %%
# Clase 1

import cv2 as cv
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('dark_background') 
path = '/Users/carlosalvarado/Desktop/ComputerVision/fotos/'

# %%
# Color image 
# (R G B) -> (B G R)

#im = cv.imread(path+'cameraman.jpg', cv.IMREAD_COLOR)
#im = cv.cvtColor(im, cv.COLOR_BGR2RGB)

# Graysclale image
im = cv.imread(path+'lenna.png', cv.IMREAD_COLOR)
#Color change, el orde de bgr a rgb
im = cv.cvtColor(im, cv.COLOR_BGR2RGB)

# %%
im.shape
# Out:
# (512, 512, 3)

# %%
type(im)
# Out:
# numpy.ndarray

# %%
#quitar la dimesión verde y azul
#im[:,:,1] = 0
#im[:,:,2] = 0

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(im,vmin=0,vmax=255)
plt.show()

# %%
im.min()
# Out:
# 7

# %%
im.max()
# Out:
# 253

# %%
# 0 No
# 255 No
